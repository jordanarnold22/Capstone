# %%
import pandas as pd
import numpy as np



pd.set_option('display.height', 1000)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
stats = pd.read_csv('stats.csv')

# %%
stats.head()
# Out:
#              Name  2003-04 2 Point Field Goal Attempts Per Game  \
# 0   Stephen Curry                                           NaN
# 1    LeBron James                                          16.1
# 2    Paul Millsap                                           NaN
# 3  Gordon Hayward                                           NaN
# 4   Blake Griffin                                           NaN
#
#    2003-04 2 Point Field Goal Percentage  \
# 0                                    NaN
# 1                                  0.438
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    2003-04 2 Point Field Goals Per Game  2003-04 3 Point Attempt Rate  \
# 0                                   NaN                           NaN
# 1                                   7.1                         0.145
# 2                                   NaN                           NaN
# ...

# %%
count_stats = [col for col in stats.columns if 'Points Per Game' in col]
stats['Years In League'] = len(stats[count_stats].columns) - stats[count_stats].isnull().sum(axis=1) - 1

# %%
stats.shape
# Out:
# (1527, 766)

# %% [markdown]
# # 2017 Free Agents

# %%
FA2017 = stats[(stats['Name'].isin(['Arron Afflalo', 'Lavoy Allen', 'Tony Allen', 'Chris Anderson', 'Alan Anderson', 'Joel Anthony',
          'Brandon Ashley', 'Luke Babbitt', 'Ron Baker', 'Leondro Barbosa', 'Matt Barnes', 'Brandon Bass',
          'Aron Baynes', 'Michael Beasley', 'Tarik Black', 'Bojan Bogdanovic', 'Andrew Bogut', 'Aaron Brooks',
          'Bobby Brown', 'Nicolas Brussino', 'Reggie Bullock', 'Trey Burke', 'Jose Calderon', 'Kentavious Caldwell-Pope',
          'Isaiah Canaan', 'Michael Carter-Williams', 'Vince Carter', 'Omri Casspi', 'Rakeem Christmas',
          'Ian Clark', 'Norris Cole', 'Darren Collison', 'Nick Collison', 'Robert Covington', 'Jamal Crawford',
          'Dante Cunningham', 'Stephen Curry', 'Dewayne Dedmon', 'Boris Diaw', 'Mike Dunleavy', 'Kevin Durant',
          'Monta Ellis', 'Tyler Ennis', 'Tyreke Evans', 'Christiano Felicio', 'Raymond Felton',
          'Yogi Ferrell', 'Randy Foye', 'Danilo Gallinari', 'Langston Galloway', 'Paul Gasol', 'Rudy Gay',
          'Taj Gibson', 'Manu Ginobili', 'Archie Goodwin', 'Jerami Grant', 'Gerald Green', 'JaMychal Green',
          'Jeff Green', 'Blake Griffin', 'Justin Hamilton', 'Tim Hardaway', 'Udonis Haslem', 'Spencer Hawes',
          'Gordon Hayward', 'Gerald Henderson', 'Roy Hibbert', 'George Hill', 'Jordan Hill', 'Darrun Hilliard',
          'Jrue Holiday', 'Justin Holiday', 'Kris Humphries', 'Serge Ibaka', 'Andre Iguodala', 'Ersan Ilyasova',
          'Joe Ingles', 'Demetrius Jackson', 'Brandon Jennings', 'Jonas Jerebko', 'Amir Johnson', 'James Johnson',
          'Dahntay Jones', 'James Jones', 'Terrence Jones', 'Ryan Kelly', 'Kyle Korver',
          'Joffrey Lauvergne', 'Ty Lawson', 'David Lee', 'Alex Len', 'DeAndre Liggins', 'Shaun Livingston',
          'Kyle Lowry', 'Shelvin Mack', 'Luc Mbah A Moute', 'James Michael McAdoo', 'K.J. McDaniels', 'JaVale McGee',
          'Ben McLemore', 'Jordan McRae', 'Josh McRoberts', 'Jodie Meeks', 'Jordan Mickey', 'C.J. Miles', 'Mike Miller',
          'Patty Mills', 'Paul Millsap', 'Nikola Mirotic', 'Greg Monroe', 'Anthony Morrow',
          'Donatas Motiejunas', 'Shabazz Muhammad', 'Mike Muscala', 'Maurice Ndour', 'Nene', 'Georges Niang',
          'Nerlens Noel', 'Dirk Nowitzki', 'David Nwaba', 'Kelly Olynyk', 'Zaza Pachulia', 'Patrick Patterson',
          'Chris Paul', 'Adreian Payne', 'Marshall Plumlee', 'Mason Plumlee', 'Otto Porter', 'Alex Poythress',
          'Ronnie Price', 'Zach Randolph', 'J.J. Redick', 'Willie Reed', 'Andre Roberson', 'Brian Roberts',
          'Thomas Robinson', 'Sergio Rodriguez', 'Rajon Rondo', 'Derrick Rose', 'Damjan Rudez', 'Brandon Rush',
          'Luis Scola', 'Mike Scott', 'Thabo Sefolosha', 'Wayne Selden', 'Ramon Sessions', 'Jonathon Simmons',
          'Tony Snell', 'Marreese Speights', 'Tiago Splitter', 'Rodney Stuckey', 'Jared Sullinger',
          'Jeff Teague', 'Jason Terry', 'Anthony Tolliver',
          'P.J. Tucker', 'Beno Udrih', 'Sasha Vujacic', 'Dwayne Wade', 'Dion Waiters', 'C.J. Watson',
          'David West', 'Alan Williams', 'Deron Williams', 'Derrick Williams', 'Troy Williams',
          'Kyle Wiltjer', 'Jeff Withey', 'Christian Wood', 'James Young', 'Nick Young', 'Tyler Zeller',
          'Stephen Zimmerman']))]

# %%
FA2017 = FA2017.drop_duplicates()

# %%
FA2017['Name'].value_counts()
# Out:
# Isaiah Canaan               3
# Demetrius Jackson           3
# DeAndre Liggins             3
# Ramon Sessions              2
# Arron Afflalo               2
# Greg Monroe                 2
# Troy Williams               2
# Ersan Ilyasova              2
# Anthony Tolliver            2
# Rajon Rondo                 2
# Jamal Crawford              2
# Andre Roberson              1
# Mike Dunleavy               1
# Blake Griffin               1
# Dante Cunningham            1
# Jodie Meeks                 1
# Darren Collison             1
# Omri Casspi                 1
# Luke Babbitt                1
# Michael Beasley             1
# Taj Gibson                  1
# Dewayne Dedmon              1
# P.J. Tucker                 1
# Marreese Speights           1
# Dirk Nowitzki               1
# Tarik Black                 1
# JaVale McGee                1
# Alex Len                    1
# Nicolas Brussino            1
# Jerami Grant                1
# Shelvin Mack                1
# ...

# %%
FA2017.head()
# Out:
#              Name  2003-04 2 Point Field Goal Attempts Per Game  \
# 0   Stephen Curry                                           NaN
# 2    Paul Millsap                                           NaN
# 3  Gordon Hayward                                           NaN
# 4   Blake Griffin                                           NaN
# 5      Kyle Lowry                                           NaN
#
#    2003-04 2 Point Field Goal Percentage  \
# 0                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
#
#    2003-04 2 Point Field Goals Per Game  2003-04 3 Point Attempt Rate  \
# 0                                   NaN                           NaN
# 2                                   NaN                           NaN
# 3                                   NaN                           NaN
# ...

# %%
FA2017[FA2017.columns[0:]].corr()['2017-18 Salary'][:-1]
# Out:
# 2003-04 2 Point Field Goal Attempts Per Game       0.608644
# 2003-04 2 Point Field Goal Percentage             -0.207178
# 2003-04 2 Point Field Goals Per Game               0.586268
# 2003-04 3 Point Attempt Rate                       0.096311
# 2003-04 3 Point Field Goal Attempts Per Game       0.174277
# 2003-04 3 Point Field Goal Percentage              0.230636
# 2003-04 3 Point Field Goals Per Game               0.159941
# 2003-04 Assist Percentage                          0.186468
# 2003-04 Assists Per Game                           0.205138
# 2003-04 Block Percentage                           0.101333
# 2003-04 Blocks Per Game                            0.305474
# 2003-04 Box Plus/Minus                             0.004842
# 2003-04 Defensive Box Plus/Minus                  -0.355499
# 2003-04 Defensive Rebound Percentage              -0.068466
# 2003-04 Defensive Rebounds Per Game                0.308489
# 2003-04 Defensive Win Shares                       0.196213
# ...

# %%
FA2017 = FA2017.set_index('Name')

# %%
FA2017.to_csv('2017_Free_Agents.csv')

# %% [markdown]
# # 2018 Free Agents

# %%
FA2018 = stats[(stats['Name'].isin(['Quincy Acy', 'Arron Afflalo', 'Kyle Anderson', 'Carmelo Anthony', 'Ryan Arcidiacono',
                                  'Trevor Ariza', 'Darrell Arther', 'Jamel Artis', 'Luke Babbitt', 'Ron Baker',
                                  'Will Barton', 'Aron Baynes', 'Michael Beasley', 'Marco Belinelli', 'Davis Bertans',
                                  'Jabari Bird', 'Nemanja Bjelica', 'Tarik Black', 'Trevor Booker', 'Avery Bradley',
                                  'Corey Brewer', 'Aaron Brooks', 'Anthony Brown', 'Lorenzo Brown', 'Markel Brown',
                                  'Bruno Caboclo', 'Jose Calderon', 'Kentavious Caldwell-Pope', 'Clint Capela',
                                  'Michael Carter Williams', 'Vince Carter', 'Omri Casspi', 'Tyler Cavanaugh',
                                  'Mario Chalmers', 'Wilson Chandler', 'Ian Clark', 'Nick Collison', 'Pat Connaughton',
                                  'Charles Cooke', 'Jack Cooley', 'Matt Costello', 'DeMarcus Cousins', 'Torrey Craig',
                                  'Jamal Crawford', 'Jordan Crawford', 'Dante Cunningham', 'Ed Davis',
                                  'Dewayne Dedmon', 'Malcolm Delaney', 'Milton Doyle', 'PJ Dozier', 'Kevin Durant',
                                  'Wayne Ellington', 'James Ennis III', 'Tyler Ennis', 'Tyreke Evans',
                                  'Dante Exum', 'Derrick Favors', 'Kay Felder', 'Raymond Felton', 'Yogi Ferrell',
                                  'Bryn Forbes', 'Tim Frazier', 'Channing Frye', 'Rudy Gay', 'Paul George',
                                   'Marcus Georges-Hunt', 'Jonathan Gibson', 'Aaron Gordon', 'Traveon Graham',
                                   'Jerami Grant', 'Danny Green', 'Gerald Green', 'Jeff Green', 'Daniel Hamilton',
                                   'Montrezl Harrell', 'Devin Harris', 'Joe Harris', 'Aaron Harrison', 'Udonis Haslem',
                                   'Mario Hezonja', 'Isaiah Hicks', 'Darrun Hilliard', 'Richaun Holmes', 'Rodney Hood',
                                   'Danuel House', 'Josh Huestis', 'Ersan Ilyasova', 'Andre Ingram', 'Jarrett Jack',
                                   'Aaron Jackson', 'Demetrius Jackson', 'LeBron James', 'Amile Jefferson', 'Richard Jefferson',
                                   'Amir Johnson', 'Joe Johnson', 'Wesley Johnson', 'Nikola Jokic', 'Derrick Jones Jr.',
                                   'DeAndre Jordan', 'Cory Joseph', 'Enes Kanter', 'Luke Kornet', 'Kosta Koufos',
                                   'Shane Larkin', 'Joffrey Lauvergne', 'Zach LaVine', 'Ty Lawson' ,'Damion Lee', 'Alex Len',
                                   'Kevon Looney', 'Brook Lopez', 'Shelvin Mack', 'Josh Magette', 'Wesley Matthews',
                                   'Luc Mbah a Moute', 'Patrick McCaw', 'T.J. McConnell', 'Erik McCree', 'Chris McCullough',
                                   'Doug McDermott', 'JaVale McGee', 'Jodie Meeks', 'Salah Mejri', 'Jordan Mickey',
                                   'Malcolm Miller', 'Nikola Mirotic', 'Greg Monroe', 'Ben Moore', 'Shabazz Muhammad',
                                   'Xavier Munford', 'Mike Muscala', 'Shabazz Napier', 'Jameer Nelson', 'Raul Neto',
                                   'Georges Niang', 'Nerlens Noel', 'Lucas Nogueira', 'Dirk Nowitzki', 'Jusuf Nurkic',
                                   'David Nwaba', "Kyle O'Quinn", 'Jahlil Okafor', 'Zaza Pachulia', 'Marcus Paige',
                                   'Jabari Parker', 'Tony Parker', 'Chris Paul', 'Gary Payton II', 'Elfrid Payton',
                                   'Kendrick Perkins', 'London Perrantes', 'Alec Peters', 'Marshall Plumlee',
                                   'Tim Quarterman', 'Julius Randle', 'J.J. Redick', 'Austin Rivers', 'Glenn Robinson III',
                                   'Rajon Rondo', 'Derrick Rose', 'JaKarr Sampson', 'Mike Scott', 'Ramon Sessions',
                                   'Iman Shumpert', 'Marcus Smart', 'Jason Smith', 'Marreese Speights', 'Nik Stauskas',
                                   'Lance Stephenson', 'Garrett Temple', 'Milos Teodosic', 'Jason Terry', 'Isaiah Thomas',
                                   'Anthony Tolliver', 'Fred VanVleet', 'Noah Vonleh', 'Dwyane Wade', 'Tyrone Wallace',
                                   'Derrick Walton Jr.', 'Travis Wear', 'James Webb III', 'David West', 'Andrew White III',
                                   'James Young', 'Joe Young', 'Nick Young', 'Thaddeus Young']))]

# %%
FA2018 = FA2018.drop_duplicates()

# %%
FA2018 = FA2018.set_index('Name')

# %%
FA2018.to_csv('2018_Free_Agents.csv')

# %% [markdown]
# # 2016 Free Agents

# %%
FA2016 = stats[(stats['Name'].isin(['Kent Bazemore', 'Kirk Hinrich', 'Kris Humphries', 'Al Horford',
                                   'Jared Sullinger', 'Tyler Zeller' 'Evan Turner', 'Markel Brown', 'Willie Reed',
                                   'Sergey Karasev', 'Henry Sims', 'Donald Sloan', 'Troy Daniels', 'Jorge Gutierrez',
                                   'Nicolas Batum', 'Tyler Hansbrough', 'Al Jefferson', 'Courtney Lee', 'Marvin Williams',
                                   'Aaron Brooks', "E'Twaun Moore", 'Joakim Noah', 'Matthew Dellavedova', 'Richard Jefferson',
                                   'James Jones', 'Timofey Mozgov', 'Dwight Powell', 'Raymond Felton', 'David Lee', 'Zaza Pachulia',
                                   'Charlie Villanueva', 'D.J. Augustin', 'Mike Miller', 'Andre Drummond', 'Steve Blake',
                                   'Anthony Tolliver', 'Harrison Barnes', 'Ian Clark', 'Festus Ezeli', 'Jmes Michael McAdoo',
                                   'Leandro Barbosa', 'Brandon Rush', 'Marreese Speights', 'Anderson Varejao', 'Terrence Jones',
                                   'Donatas Motiejunas', 'Josh Smith', 'Jason Terry', 'Jordan Hill', 'Solomon Hill', 'Ty Lawson',
                                   'Ian Mahinmi', 'Jeff Ayres', 'Jamal Crawford', 'Jeff Green', 'Luc Mbah a Moute', 'Pablo Prigioni',
                                   'Tarik Black', 'Jordan Clarkson', 'Marcelo Huertas', 'Ryan Kelly', 'Roy Hibbert', 'Robert Sacre',
                                   'Bryce Cotton', 'Chris Anderson', 'Matt Barnes', 'Mike Conley', 'Jordan Farmar', 'P.J. Hairston',
                                   'Ryan Hollins', 'Tyler Johnson', 'Luol Deng', 'Gerald Green', 'Udonis Haslem', 'Joe Johnson',
                                   'Dwyane Wade', 'Hassan Whiteside', 'Dorell Wright', 'Miles Plumlee', 'Jerryd Bayless', 'O.J. Mayo',
                                   'Steve Novak', 'Greivis Vasquez', 'Tayshaun Prince', 'James Ennis', 'Tim Frazier', 'Ryan Anderson',
                                   'Norris Cole', 'Eric Gordon', 'Jordan Hamilton', 'Kendrick Perkins', 'Cleanthony Early',
                                   'Langston Galloway', 'Lou Amundson', 'Kevin Seraphin', 'Lance Thomas', 'Sasha Vujacic',
                                   'Dion Waiters', 'Kevin Durant', 'Randy Foye', 'Nazr Mohammed', 'Dewayne Dedmon', 'Evan Fournier',
                                   'Andrew Nicholson', 'Brandon Jennings', 'Jason Smith', 'Isaiah Canaan', 'Christian Wood',
                                   'Elton Brand', 'Ish Smith', 'Chase Budinger', 'Jon Leuer', 'Ronnie Price', 'Mirza Teletovic',
                                   'Allen Crabbe', 'Maurice Harkless', 'Meyers Leonard', 'Gerald Henderson', 'Chris Kaman',
                                   'Brian Roberts', 'Seth Curry', 'Quincy Acy', 'James Anderson', 'Rajon Rondo',
                                   'Boban Marjanovic', 'Matt Bonner', 'Kevin Martin', 'Andre Miller', 'Terrence Ross',
                                   'James Johnson', 'Luis Scola', 'Jason Thompson', 'Trevor Booker', 'Bradley Beal',
                                   'Alan Anderson', 'Jared Dudley', 'J.J. Hickson', 'Nene Hilario', 'Ramon Sessions', 'Garrett Temple',
                                   ]))]

# %%
FA2016.shape
# Out:
# (264, 766)

# %%
FA2016 = FA2016.drop_duplicates()

# %%
FA2016 = FA2016.set_index('Name')

# %%
FA2016.to_csv('2016_Free_Agents.csv')

# %% [markdown]
# # 2015 Free Agents

# %%
FA2015 = stats[(stats['Name'].isin(['Marc Gasol', 'Kevin Love', 'Kawhi Leonard', 'Jimmy Bulter', 'DeAndre Jordan', 'Goran Dragic',
                                    'LaMarcus Aldridge', 'Tristan Thompson', 'Draymond Green', 'Reggie Jackson', 'Enes Kanter',
                                    'Wesley Matthews', 'Brandon Knight', 'Khris Middleton', 'Tobias Harris', 'Brook Lopez',
                                    'Paul Millsap', 'DeMarre Carroll', 'Omer Asik', 'Robin Lopez', 'Thaddeus Young', 'Tyson Chandler',
                                    'Greg Monroe', 'Monta Ellis', 'Danny Green', 'Iman Shumpert', 'Jae Crowder', 'Kosta Koufos',
                                    'Al-Farouq Aminu', 'Cory Joseph', 'Amir Johnson', 'Corey Brewer', 'Patrick Beverley', 'Lou Williams',
                                    'Ed Davis', 'Aron Baynes', 'Alexis Ajinca', 'Marco Belinelli', 'Kyle Singler', 'Brandan Wright',
                                    'Kevin Garnett', "Kyle O'Quinn", 'J.J. Barea', 'Arron Afflalo', 'C.J. Watson', 'Mike Dunleavy',
                                    'Jameer Nelson', 'Deron Williams', 'Tim Duncan', 'Will Barton', 'Paul Pierce', 'Jonas Jerebko',
                                    'Rajon Rondo', 'Derrick Williams', 'Dante Cunningham', 'LaVoy Allen', 'Drew Gooden', 'K.J. McDaniels',
                                    'Austin Rivers', 'Brandon Bass', 'Omri Casspi', 'Darrell Arthur', 'Manu Ginobili', 'Mirza Teletovic',
                                    'Joel Anthony', 'Jeremy Lin', 'Jason Smith', 'Joe Ingles', 'Mo Williams', 'Jordan Hill', 'Alan Anderson',
                                    'Glen Robinson', 'John Jenkins', 'Wayne Ellington', 'Caron Butler', 'David West', 'Norris Cole',
                                    'Shane Larkin', 'Andrea Bargnani', 'Luis Scola', 'Kevin Seraphin', 'Alonzo Gee', 'Pierre Jackson',
                                    'Leondro Barbosa', 'Jeremy Evans', 'Luke Babbitt', 'Wesley Johnson', 'Aaron Brooks', 'James Anderson',
                                    'Gary Neal', 'Quincy Acy', 'Thomas Robinson', 'Jeff Withey', 'Justin Holiday', 'Shayne Whittington',
                                    'Lance Thomas', 'Louis Amundson', 'Dahntay Jones', 'Chuck Hayes', 'Jason Terry', 'Tayshaun Prince',
                                    'Jason Richardson', 'Charlie Villanueva', 'Richard Jefferson', 'Kendrick Perkins', 'James Jones',
                                    'Ronnie Price', 'Josh Smith', 'Matt Bonner', "Amar'e Stoudemire", 'Ronald Roberts', 'Gerald Green',
                                    'Tyler Hansbrough', 'Chris Copeland', 'Matthew Dellavedova', 'Ishmael Smith', 
                                    'Donald Sloan', 'Jimmer Fredette', 'Pablo Prigioni', 'Anthony Bennett', 'Ian Clark', 'Phil Pressey',
                                    'Eric Moreland', 'LeBron James', 'Dwyane Wade', 'Gerald Wallace', 'Glen Davis',
                                    'Landry Fields', 'J.R. Smith', 'Andre Miller', 'Luc Mbah a Moute', 'Ben Gordon', 'Brendan Haywood',
                                    'Carlos Boozer', 'Bismack Biyombo', 'Alexey Shved', 'Dorell Wright', 'Joel Freeland', 'Luke Ridnour',
                                    'Elton Brand', 'Jeff Ayres', 'Luigi Datome', 'Zoran Dragic', 'Reggie Evans', 'Ronny Turiaf',
                                    'Hedo Turkoglu', 'Rasual Butler', 'Shawn Marion', 'Nazr Mohammed', 'Willie Green', 'Jason Maxiell',
                                    'Ryan Hollins', 'Shawne Williams', 'Rodney Stuckey', 'Joey Dorsey', 'Greg Stiemsma',
                                    'Robbie Hummel', 'Darius Morris', 'Henry Sims', 'Jerome Jordan', 'Jeff Taylor', 'Cory Jefferson',
                                    'Toney Douglas', 'Nick Calathes', 'Ognjen Kuzmic', 'Austin Daye', 'Earl Clark', 'Henry Walker',
                                    'Jordan Hamilton', 'Jamaal Franklin', 'Greg Smith', 'John Lucas',
                                    'Bernard James', 'Michael Beasley', 'Will Bynum', 'Arinze Onuaku', 'Earl Barron',
                                    'Lester Hudson', 'Jerel McNeal', 'Ricky Ledo', 'Nando De Colo'
                                   ]))]

# %%
FA2015.shape
# Out:
# (277, 766)

# %%
FA2015 = FA2015.drop_duplicates()

# %%
FA2015 = FA2015.set_index('Name')

# %%
FA2015.to_csv('2015_Free_Agents.csv')

# %% [markdown]
# # 2014 Free Agents

# %%
FA2014 = stats[(stats['Name'].isin(['Lebron James', 'Chris Bosh', 'Carmelo Anthony', 'Dwyane Wade',
                                    'Dirk Nowitzki', 'Greg Monroe', 'Kyle Lowry', 'Chandler Parsons',
                                    'Lance Stephenson', 'Marcin Gortat', 'Gordon Hayward', 'Isaiah Thomas',
                                    'Zach Randolph', 'Luol Deng', 'Pau Gasol', 'Avery Bradley', 'Paul Pierce',
                                    'Jordan Hill', 'Channing Frye', 'Trevor Ariza', 'Shaun Livingston',
                                    'Spencer Hawes', 'Greivis Vasquez', 'Anthony Morrow', 'Vince Carter',
                                    'Marvin Williams', 'Darren Collison', 'Nick Young', 'Rodney Stuckey',
                                    'Mario Chalmers', 'Patrick Patterson', 'Jimmer Fredette', 'Kris Humphries',
                                    'Jerryd Bayless', 'C.J. Miles', 'Mo Williams', "Amar'e Stoudemire", 'Boris Diaw',
                                    'Ed Davis', 'Jodie Meeks', 'Patty Mills', 'Jordan Farmar', 'P.J. Tucker',
                                    'Chris Anderson', 'Glen Davis', 'DeJuan Blair', 'Jason Smith', 'Josh McRoberts',
                                    'Beno Udrih', 'Steve Blake', 'Al-Farouq Aminu', 'Caron Butler', 'LaVoy Allen',
                                    'Mike Miller', 'Thabo Sefolosha', 'Danny Granger', 'Xavier Henry', 'Devin Harris',
                                    'Trevor Booker', 'Alan Anderson', 'Anthony Tolliver', 'Ben Gordon',
                                    'Brandon Rush', 'Brian Roberts', 'Carlos Boozer', 'Cartier Martin',
                                    'Chris Kaman', 'D.J. Augustin', 'Damjan Rudez', 'Darius Miller',
                                    'Drew Gooden', 'Garrett Temple', 'Greg Smith', 'Jameer Nelson',
                                    'James Jones', 'Jannero Pargo', 'Jeff Adrien', 'Joel Anthony', 'John Salmons',
                                    'Kendall Marshall', 'Kent Bazemore', 'Kirk Hinrich', 'Luke Ridnour', 'Matt Bonner',
                                    'Richard Jefferson', 'Ryan Kelly', 'Shelvin Mack', 'Wesley Johnson',
                                    'Willie Green']))]

# %%
FA2014.shape
# Out:
# (160, 766)

# %%
FA2014 = FA2014.drop_duplicates()

# %%
FA2014.shape
# Out:
# (56, 766)

# %%
FA2014 = FA2014.set_index('Name')

# %%
FA2014.to_csv('2014_Free_Agents.csv')
