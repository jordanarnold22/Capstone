# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import regex as re
import wikipedia as wp

pd.set_option('display.height', 1000)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %% [markdown]
# # 2018 Free Agent Scraping

# %%
html = wp.page("List of 2018–19 NBA season transactions").html().encode("UTF-8")
FA2018 = pd.read_html(html)[5]
FA2018.head()
# Out:
#                              0               1  \
# 0                       Player     Date signed
# 1  Derrick Jones Jr.**** (RFA)          July 1
# 2                Thomas Bryant          July 2
# 3               Brad Wanamaker  Boston Celtics
# 4                 Derrick Rose          July 4
#
#                                          2  \
# 0                                 New team
# 1                               Miami Heat
# 2  Washington Wizards(Claimed off waivers)
# 3             FenerbahÃ§e DoÄuÅ (Turkey)
# 4                   Minnesota Timberwolves
#
#                                        3     4
# 0                            Former team   Ref
# 1                                   [67]   NaN
# 2  Los Angeles Lakers(Waived on June 30)  [68]
# 3                                   [69]   NaN
# 4                                   [70]   NaN

# %%
FA2018 = FA2018[:109]

# %%
FA2018[0] = FA2018[0].str.replace('*','')
FA2018[0] = FA2018[0].str.replace('(RFA)','')
FA2018[0] = FA2018[0].str.replace(')','')
FA2018[0] = FA2018[0].str.replace('(','')
FA2018[0] = FA2018[0].str.replace('[','')
FA2018[0] = FA2018[0].str.replace('v]','')
FA2018[0] = FA2018[0].str.replace('e]','')
FA2018[0] = FA2018[0].str.replace('P. J.', 'P.J.')
FA2018[0] = FA2018[0].str.replace('J. J.', 'J.J.')
FA2018[0] = FA2018[0].str.replace('C. J.', 'C.J.')
FA2018[0] = FA2018[0].str.replace('K. J.', 'K.J.')
FA2018[0] = FA2018[0].str.replace('L. J.', 'L.J.')
FA2018[0] = FA2018[0].str.replace('V. J.', 'V.J.')
FA2018[0] = FA2018[0].str.replace('ć', 'c')
FA2018[0] = FA2018[0].str.replace('ê', 'e')
FA2018[0] = FA2018[0].str.replace('í', 'i')
FA2018[0] = FA2018[0].str.replace('š', 's')
FA2018[0] = FA2018[0].str.replace('é', 'e')
FA2018[0] = FA2018[0].str.replace('İ', 'I')
FA2018[0] = FA2018[0].str.replace('ž', 'z')
FA2018[0] = FA2018[0].str.replace('Ä', 'c')
FA2018[0] = FA2018[0].str.replace('ó','o')
FA2018[0] = FA2018[0].str.replace('Ã©', 'e')
FA2018[0] = FA2018[0].str.replace('Ã³', 'o')
FA2018[0] = FA2018[0].str.replace('Ä°', 'I')
FA2018[0] = FA2018[0].str.replace('Ä', 'a')
FA2018 = FA2018[FA2018[2].str.contains('Turkey') == False]
FA2018 = FA2018[FA2018[2].str.contains('Estonia') == False]
FA2018 = FA2018[FA2018[2].str.contains('Undrafted') == False]
FA2018 = FA2018[FA2018[3].str.contains('Undrafted') == False]
FA2018 = FA2018[FA2018[2].str.contains('Russia') == False]
FA2018 = FA2018[FA2018[2].str.contains('China') == False]
FA2018 = FA2018[FA2018[2].str.contains('Lebanon') == False]
FA2018 = FA2018[FA2018[3].str.contains('Belgium') == False]

# %%
FA2018.head()
# Out:
#                     0                       1  \
# 0              Player             Date signed
# 1  Derrick Jones Jr.                   July 1
# 2       Thomas Bryant                  July 2
# 4        Derrick Rose                  July 4
# 6        Nik Stauskas  Portland Trail Blazers
#
#                                          2  \
# 0                                 New team
# 1                               Miami Heat
# 2  Washington Wizards(Claimed off waivers)
# 4                   Minnesota Timberwolves
# 6                            Brooklyn Nets
#
#                                        3     4
# 0                            Former team   Ref
# 1                                   [67]   NaN
# 2  Los Angeles Lakers(Waived on June 30)  [68]
# 4                                   [70]   NaN
# 6                                   [72]   NaN

# %%
FA2018 = FA2018[0]

# %%
FA2018.head()
# Out:
# 0                Player
# 1    Derrick Jones Jr.
# 2         Thomas Bryant
# 4          Derrick Rose
# 6          Nik Stauskas
# Name: 0, dtype: object

# %%
FA2018.to_csv('2018_Free_Agents.csv', index=False)

# %% [markdown]
# # 2017 Free Agent Scraping

# %%
html = wp.page("List of 2017–18 NBA season transactions").html().encode("UTF-8")
FA2017 = pd.read_html(html)[6]
FA2017.head()
# Out:
#                          0                                         1  \
# 0                   Player                               Date signed
# 1       Wayne Selden Jr.**                                    July 1
# 2  Cristiano Felício (RFA)                                    July 6
# 3        Danilo Gallinari*  Los Angeles Clippers(via sign and trade)
# 4       Langston Galloway*                           Detroit Pistons
#
#                    2            3    4
# 0           New team  Former team  Ref
# 1  Memphis Grizzlies        [103]  NaN
# 2      Chicago Bulls        [104]  NaN
# 3     Denver Nuggets         [61]  NaN
# 4   Sacramento Kings        [105]  NaN

# %%
FA2017 = FA2017[:225]

# %%
FA2017[0] = FA2017[0].str.replace('*','')
FA2017[0] = FA2017[0].str.replace('(RFA)','')
FA2017[0] = FA2017[0].str.replace(')','')
FA2017[0] = FA2017[0].str.replace('(','')
FA2017[0] = FA2017[0].str.replace('[','')
FA2017[0] = FA2017[0].str.replace('v]','')
FA2017[0] = FA2017[0].str.replace('e]','')
FA2017[0] = FA2017[0].str.replace('P. J.', 'P.J.')
FA2017[0] = FA2017[0].str.replace('J. J.', 'J.J.')
FA2017[0] = FA2017[0].str.replace('C. J.', 'C.J.')
FA2017[0] = FA2017[0].str.replace('K. J.', 'K.J.')
FA2017[0] = FA2017[0].str.replace('L. J.', 'L.J.')
FA2017[0] = FA2017[0].str.replace('V. J.', 'V.J.')
FA2017[0] = FA2017[0].str.replace('ć', 'c')
FA2017[0] = FA2017[0].str.replace('ê', 'e')
FA2017[0] = FA2017[0].str.replace('í', 'i')
FA2017[0] = FA2017[0].str.replace('š', 's')
FA2017[0] = FA2017[0].str.replace('é', 'e')
FA2017[0] = FA2017[0].str.replace('İ', 'I')
FA2017[0] = FA2017[0].str.replace('ž', 'z')
FA2017[0] = FA2017[0].str.replace('ó','o')

# %%
FA2017 = FA2017[FA2017[2].str.contains('undrafted') == False]
FA2017 = FA2017[FA2017[2].str.contains('D-League') == False]
FA2017 = FA2017[FA2017[2].str.contains('Spain') == False]
FA2017 = FA2017[FA2017[2].str.contains('Argentina') == False]
FA2017 = FA2017[FA2017[2].str.contains('Russia') == False]
FA2017 = FA2017[FA2017[2].str.contains('China') == False]
FA2017 = FA2017[FA2017[2].str.contains('Greece') == False]
FA2017 = FA2017[FA2017[2].str.contains('Israel') == False]
FA2017 = FA2017[FA2017[2].str.contains('G League') == False]
FA2017 = FA2017[FA2017[2].str.contains('Italy') == False]
FA2017 = FA2017[FA2017[2].str.contains('Philippines') == False]
FA2017 = FA2017[FA2017[2].str.contains('France') == False]
FA2017 = FA2017[FA2017[2].str.contains('Turkey') == False]
FA2017 = FA2017[FA2017[2].str.contains('Germany') == False]

# %%
FA2017 = FA2017[0]

# %%
FA2017.to_csv('2017_Free_Agents.csv', index=False)

# %% [markdown]
# # 2016 Free Agent Scraping

# %%
html = wp.page("List of 2016–17 NBA season transactions").html().encode("UTF-8")
FA2016 = pd.read_html(html)[5]
FA2016.head()
# Out:
#                    0                   1  \
# 0             Player         Date signed
# 1     Tony Wroten[e]             June 24
# 2      Shawn Long[e]              July 3
# 3  James Webb III[e]  Philadelphia 76ers
# 4     D. J. Augustin              July 7
#
#                                         2  \
# 0                                New team
# 1  Memphis Grizzlies(claimed off waivers)
# 2                      Philadelphia 76ers
# 3          Boise State(undrafted in 2016)
# 4                           Orlando Magic
#
#                                           3          4
# 0                               Former team        Ref
# 1        New York Knicks(waived on June 12)  [84][141]
# 2  LouisianaâLafayette(undrafted in 2016)  [84][142]
# 3                                 [84][142]        NaN
# 4                            Denver Nuggets      [143]

# %%
FA2016 = FA2016[:233]

# %%
FA2016[0] = FA2016[0].str.replace('*','')
FA2016[0] = FA2016[0].str.replace('(RFA)','')
FA2016[0] = FA2016[0].str.replace(')','')
FA2016[0] = FA2016[0].str.replace('(','')
FA2016[0] = FA2016[0].str.replace('[','')
FA2016[0] = FA2016[0].str.replace('v]','')
FA2016[0] = FA2016[0].str.replace('e]','')
FA2016[0] = FA2016[0].str.replace('x]','')
FA2016[0] = FA2016[0].str.replace('aa]','')
FA2016[0] = FA2016[0].str.replace(']','')
FA2016[0] = FA2016[0].str.replace('P. J.', 'P.J.')
FA2016[0] = FA2016[0].str.replace('J. J.', 'J.J.')
FA2016[0] = FA2016[0].str.replace('C. J.', 'C.J.')
FA2016[0] = FA2016[0].str.replace('K. J.', 'K.J.')
FA2016[0] = FA2016[0].str.replace('L. J.', 'L.J.')
FA2016[0] = FA2016[0].str.replace('V. J.', 'V.J.')
FA2016[0] = FA2016[0].str.replace('J. P.', 'J.P.')
FA2016[0] = FA2016[0].str.replace('D. J.', 'D.J.')
FA2016[0] = FA2016[0].str.replace('ć', 'c')
FA2016[0] = FA2016[0].str.replace('ê', 'e')
FA2016[0] = FA2016[0].str.replace('í', 'i')
FA2016[0] = FA2016[0].str.replace('š', 's')
FA2016[0] = FA2016[0].str.replace('é', 'e')
FA2016[0] = FA2016[0].str.replace('İ', 'I')
FA2016[0] = FA2016[0].str.replace('ž', 'z')
FA2016[0] = FA2016[0].str.replace('ó', 'o')

FA2016[0] = FA2016[0].str.replace('Ä', 'A')
FA2016[0] = FA2016[0].str.replace('Ã¡', 'A')
FA2016[0] = FA2016[0].str.replace('Ã³', 'i')
FA2016[0] = FA2016[0].str.replace('Ãª', 'e')
FA2016[0] = FA2016[0].str.replace('Ã£o', 'ao')
FA2016[0] = FA2016[0].str.replace('AiA', 'cic')
FA2016[0] = FA2016[0].str.replace('Ã­', 'i')
FA2016[0] = FA2016[0].str.replace('A', 'c')

# %%
FA2016 = FA2016[FA2016[2].str.contains('undrafted') == False]
FA2016 = FA2016[FA2016[2].str.contains('D-League') == False]
FA2016 = FA2016[FA2016[2].str.contains('Spain') == False]
FA2016 = FA2016[FA2016[2].str.contains('Argentina') == False]
FA2016 = FA2016[FA2016[2].str.contains('Russia') == False]
FA2016 = FA2016[FA2016[2].str.contains('China') == False]
FA2016 = FA2016[FA2016[2].str.contains('Greece') == False]
FA2016 = FA2016[FA2016[2].str.contains('Israel') == False]

# %%
FA2016 = FA2016[0]

# %%
FA2016.head()
# Out:
# 0           Player
# 1      Tony Wroten
# 2       Shawn Long
# 4    D.J. Augustin
# 5      Matt Barnes
# Name: 0, dtype: object

# %%
FA2016.to_csv('2016_Free_Agents.csv', index=False)

# %% [markdown]
# # 2015 Free Agents

# %%
html = wp.page("List of 2015–16 NBA season transactions").html().encode("UTF-8")
FA2015 = pd.read_html(html)[6]
FA2015.head()
# Out:
#                    0                     1                       2  \
# 0             Player           Date signed                New team
# 1     Ryan Boatright                July 2           Brooklyn Nets
# 2      Arron Afflalo                July 9         New York Knicks
# 3     Alexis AjinÃ§a  New Orleans Pelicans                    [97]
# 4  LaMarcus Aldridge     San Antonio Spurs  Portland Trail Blazers
#
#                                                3     4
# 0                                    Former team   Ref
# 1  Connecticut(went undrafted in the 2015 Draft)  [96]
# 2                         Portland Trail Blazers  [64]
# 3                                            NaN   NaN
# 4                                           [98]   NaN

# %%
FA2015 = FA2015[:257]

# %%
FA2015[0] = FA2015[0].str.replace('*','')
FA2015[0] = FA2015[0].str.replace('(RFA)','')
FA2015[0] = FA2015[0].str.replace(')','')
FA2015[0] = FA2015[0].str.replace('(','')
FA2015[0] = FA2015[0].str.replace('[','')
FA2015[0] = FA2015[0].str.replace('v]','')
FA2015[0] = FA2015[0].str.replace('e]','')
FA2015[0] = FA2015[0].str.replace('x]','')
FA2015[0] = FA2015[0].str.replace('aa]','')
FA2015[0] = FA2015[0].str.replace(']','')
FA2015[0] = FA2015[0].str.replace('P. J.', 'P.J.')
FA2015[0] = FA2015[0].str.replace('J. J.', 'J.J.')
FA2015[0] = FA2015[0].str.replace('C. J.', 'C.J.')
FA2015[0] = FA2015[0].str.replace('K. J.', 'K.J.')
FA2015[0] = FA2015[0].str.replace('L. J.', 'L.J.')
FA2015[0] = FA2015[0].str.replace('V. J.', 'V.J.')
FA2015[0] = FA2015[0].str.replace('J. P.', 'J.P.')
FA2015[0] = FA2015[0].str.replace('D. J.', 'D.J.')
FA2015[0] = FA2015[0].str.replace('J. R.', 'J.R.')
FA2015[0] = FA2015[0].str.replace('T. J.', 'T.J.')
FA2015[0] = FA2015[0].str.replace('ć', 'c')
FA2015[0] = FA2015[0].str.replace('ê', 'e')
FA2015[0] = FA2015[0].str.replace('í', 'i')
FA2015[0] = FA2015[0].str.replace('š', 's')
FA2015[0] = FA2015[0].str.replace('é', 'e')
FA2015[0] = FA2015[0].str.replace('İ', 'I')
FA2015[0] = FA2015[0].str.replace('ž', 'z')
FA2015[0] = FA2015[0].str.replace('ó', 'o')

FA2015[0] = FA2015[0].str.replace('Ã©', 'e')
FA2015[0] = FA2015[0].str.replace('Ã³', 'o')
FA2015[0] = FA2015[0].str.replace('Ä', 'c')
FA2015[0] = FA2015[0].str.replace('Ã§', 'c')
FA2015[0] = FA2015[0].str.replace('Ã', 'O')
FA2015[0] = FA2015[0].str.replace('ÅÄ±', 'si')

# %%
FA2015 = FA2015[FA2015[2].str.contains('undrafted') == False]
FA2015 = FA2015[FA2015[2].str.contains('D-League') == False]
FA2015 = FA2015[FA2015[2].str.contains('Spain') == False]
FA2015 = FA2015[FA2015[2].str.contains('Argentina') == False]
FA2015 = FA2015[FA2015[2].str.contains('Russia') == False]
FA2015 = FA2015[FA2015[2].str.contains('China') == False]
FA2015 = FA2015[FA2015[2].str.contains('Greece') == False]
FA2015 = FA2015[FA2015[2].str.contains('Israel') == False]
FA2015 = FA2015[FA2015[2].str.contains('G League') == False]
FA2015 = FA2015[FA2015[2].str.contains('Italy') == False]
FA2015 = FA2015[FA2015[2].str.contains('Philippines') == False]
FA2015 = FA2015[FA2015[2].str.contains('France') == False]
FA2015 = FA2015[FA2015[2].str.contains('Turkey') == False]
FA2015 = FA2015[FA2015[2].str.contains('Germany') == False]
FA2015 = FA2015[FA2015[2].str.contains('Estonia') == False]
FA2015 = FA2015[FA2015[2].str.contains('Hungary') == False]
FA2015 = FA2015[FA2015[2].str.contains('Dominican Republic') == False]
FA2015 = FA2015[FA2015[2].str.contains('Puerto Rico') == False]
FA2015 = FA2015[FA2015[2].str.contains('Lebanon') == False]
FA2015 = FA2015[FA2015[2].str.contains('Australia') == False]
FA2015 = FA2015[FA2015[2].str.contains('Iraq') == False]
FA2015 = FA2015[FA2015[2].str.contains('Slovenia') == False]
FA2015 = FA2015[FA2015[2].str.contains('Belgium') == False]
FA2015 = FA2015[FA2015[2].str.contains('Serbia') == False]
FA2015 = FA2015[FA2015[2].str.contains('Brazil') == False]

# %%
FA2015 = FA2015[0]

# %%
FA2015.head()
# Out:
# 0               Player
# 1       Ryan Boatright
# 2        Arron Afflalo
# 3        Alexis Ajinca
# 4    LaMarcus Aldridge
# Name: 0, dtype: object

# %%
FA2015.to_csv('2015_Free_Agents.csv', index=False)

# %% [markdown]
# # 2014 Free Agents

# %%
html = wp.page("List of 2014–15 NBA season transactions").html().encode("UTF-8")
FA2014 = pd.read_html(html)[5]
FA2014.head()
# Out:
#                     0            1                                   2  \
# 0              Player  Date signed                            New team
# 1        Willie Green      June 30  Orlando Magic(claimed off waivers)
# 2  Shayne Whittington       July 2                      Indiana Pacers
# 3        Bryce Cotton       July 7                   San Antonio Spurs
# 4         Steve Blake      July 10              Portland Trail Blazers
#
#                                                    3      4
# 0                                        Former team    Ref
# 1            Los Angeles Clippers(waived on June 29)  [110]
# 2  Western Michigan(went undrafted in the 2014 Dr...  [111]
# 3       Providence(went undrafted in the 2014 Draft)  [112]
# 4                              Golden State Warriors  [113]

# %%
FA2014 = FA2014[:233]

# %%
FA2014[0] = FA2014[0].str.replace('*','')
FA2014[0] = FA2014[0].str.replace('(RFA)','')
FA2014[0] = FA2014[0].str.replace(')','')
FA2014[0] = FA2014[0].str.replace('(','')
FA2014[0] = FA2014[0].str.replace('[','')
FA2014[0] = FA2014[0].str.replace('v]','')
FA2014[0] = FA2014[0].str.replace('e]','')
FA2014[0] = FA2014[0].str.replace('x]','')
FA2014[0] = FA2014[0].str.replace('aa]','')
FA2014[0] = FA2014[0].str.replace(']','')
FA2014[0] = FA2014[0].str.replace('P. J.', 'P.J.')
FA2014[0] = FA2014[0].str.replace('J. J.', 'J.J.')
FA2014[0] = FA2014[0].str.replace('C. J.', 'C.J.')
FA2014[0] = FA2014[0].str.replace('K. J.', 'K.J.')
FA2014[0] = FA2014[0].str.replace('L. J.', 'L.J.')
FA2014[0] = FA2014[0].str.replace('V. J.', 'V.J.')
FA2014[0] = FA2014[0].str.replace('J. P.', 'J.P.')
FA2014[0] = FA2014[0].str.replace('D. J.', 'D.J.')
FA2014[0] = FA2014[0].str.replace('J. R.', 'J.R.')
FA2014[0] = FA2014[0].str.replace('T. J.', 'T.J.')
FA2014[0] = FA2014[0].str.replace('A. J.', 'A.J.')
FA2014[0] = FA2014[0].str.replace('ć', 'c')
FA2014[0] = FA2014[0].str.replace('ê', 'e')
FA2014[0] = FA2014[0].str.replace('í', 'i')
FA2014[0] = FA2014[0].str.replace('š', 's')
FA2014[0] = FA2014[0].str.replace('é', 'e')
FA2014[0] = FA2014[0].str.replace('İ', 'I')
FA2014[0] = FA2014[0].str.replace('ž', 'z')
FA2014[0] = FA2014[0].str.replace('ó', 'o')
FA2014[0] = FA2014[0].str.replace('á', 'a')
FA2014[0] = FA2014[0].str.replace('ü', 'u')
FA2014[0] = FA2014[0].str.replace('ğ', 'g')

FA2014[0] = FA2014[0].str.replace('P.ice', ' Price')

# %%
FA2014 = FA2014[FA2014[2].str.contains('undrafted') == False]
FA2014 = FA2014[FA2014[2].str.contains('D-League') == False]
FA2014 = FA2014[FA2014[2].str.contains('Spain') == False]
FA2014 = FA2014[FA2014[2].str.contains('Argentina') == False]
FA2014 = FA2014[FA2014[2].str.contains('Russia') == False]
FA2014 = FA2014[FA2014[2].str.contains('China') == False]
FA2014 = FA2014[FA2014[2].str.contains('Greece') == False]
FA2014 = FA2014[FA2014[2].str.contains('Israel') == False]
FA2014 = FA2014[FA2014[2].str.contains('G League') == False]
FA2014 = FA2014[FA2014[2].str.contains('Italy') == False]
FA2014 = FA2014[FA2014[2].str.contains('Philippines') == False]
FA2014 = FA2014[FA2014[2].str.contains('France') == False]
FA2014 = FA2014[FA2014[2].str.contains('Turkey') == False]
FA2014 = FA2014[FA2014[2].str.contains('Germany') == False]
FA2014 = FA2014[FA2014[2].str.contains('Estonia') == False]
FA2014 = FA2014[FA2014[2].str.contains('Hungary') == False]
FA2014 = FA2014[FA2014[2].str.contains('Dominican Republic') == False]
FA2014 = FA2014[FA2014[2].str.contains('Puerto Rico') == False]
FA2014 = FA2014[FA2014[2].str.contains('Lebanon') == False]
FA2014 = FA2014[FA2014[2].str.contains('Australia') == False]
FA2014 = FA2014[FA2014[2].str.contains('Iraq') == False]
FA2014 = FA2014[FA2014[2].str.contains('Slovenia') == False]
FA2014 = FA2014[FA2014[2].str.contains('Belgium') == False]
FA2014 = FA2014[FA2014[2].str.contains('Serbia') == False]
FA2014 = FA2014[FA2014[2].str.contains('Brazil') == False]
FA2014 = FA2014[FA2014[2].str.contains('Venezuela') == False]

# %%
FA2014 = FA2014[0]

# %%
FA2014.to_csv('2014_Free_Agents.csv', index=False)

# %% [markdown]
# # 2013 Free Agents

# %%
html = wp.page("List of 2013–14 NBA season transactions").html().encode("UTF-8")
FA2013 = pd.read_html(html)[7]
FA2013.head()
# Out:
#                  0                     1                     2  \
# 0           Player           Date signed              New team
# 1     Donald Sloan                July 3        Indiana Pacers
# 2  Al-Farouq Aminu               July 10  New Orleans Pelicans
# 3   Chris Andersen            Miami Heat                 [103]
# 4      Matt Barnes  Los Angeles Clippers                 [104]
#
#                                    3      4
# 0                        Former team    Ref
# 1  Guangdong Southern Tigers (China)  [101]
# 2                              [102]    NaN
# 3                                NaN    NaN
# 4                                NaN    NaN

# %%
FA2013 = FA2013[:260]

# %%
FA2013[0] = FA2013[0].str.replace('*','')
FA2013[0] = FA2013[0].str.replace('(RFA)','')
FA2013[0] = FA2013[0].str.replace(')','')
FA2013[0] = FA2013[0].str.replace('(','')
FA2013[0] = FA2013[0].str.replace('[','')
FA2013[0] = FA2013[0].str.replace('v]','')
FA2013[0] = FA2013[0].str.replace('e]','')
FA2013[0] = FA2013[0].str.replace('x]','')
FA2013[0] = FA2013[0].str.replace('aa]','')
FA2013[0] = FA2013[0].str.replace(']','')
FA2013[0] = FA2013[0].str.replace('P. J.', 'P.J.')
FA2013[0] = FA2013[0].str.replace('J. J.', 'J.J.')
FA2013[0] = FA2013[0].str.replace('C. J.', 'C.J.')
FA2013[0] = FA2013[0].str.replace('K. J.', 'K.J.')
FA2013[0] = FA2013[0].str.replace('L. J.', 'L.J.')
FA2013[0] = FA2013[0].str.replace('V. J.', 'V.J.')
FA2013[0] = FA2013[0].str.replace('J. P.', 'J.P.')
FA2013[0] = FA2013[0].str.replace('D. J.', 'D.J.')
FA2013[0] = FA2013[0].str.replace('J. R.', 'J.R.')
FA2013[0] = FA2013[0].str.replace('T. J.', 'T.J.')
FA2013[0] = FA2013[0].str.replace('A. J.', 'A.J.')
FA2013[0] = FA2013[0].str.replace('O. J.', 'O.J.')
FA2013[0] = FA2013[0].str.replace('ć', 'c')
FA2013[0] = FA2013[0].str.replace('ê', 'e')
FA2013[0] = FA2013[0].str.replace('í', 'i')
FA2013[0] = FA2013[0].str.replace('š', 's')
FA2013[0] = FA2013[0].str.replace('é', 'e')
FA2013[0] = FA2013[0].str.replace('İ', 'I')
FA2013[0] = FA2013[0].str.replace('ž', 'z')
FA2013[0] = FA2013[0].str.replace('ó', 'o')
FA2013[0] = FA2013[0].str.replace('á', 'a')
FA2013[0] = FA2013[0].str.replace('ü', 'u')
FA2013[0] = FA2013[0].str.replace('ğ', 'g')

FA2013[0] = FA2013[0].str.replace('P.ice', ' Price')
FA2013[0] = FA2013[0].str.replace('R.dick', ' Redick')
FA2013[0] = FA2013[0].str.replace('A.J.fferson', 'Al Jefferson')

# %%
FA2013 = FA2013[FA2013[2].str.contains('undrafted') == False]
FA2013 = FA2013[FA2013[2].str.contains('D-League') == False]
FA2013 = FA2013[FA2013[2].str.contains('Spain') == False]
FA2013 = FA2013[FA2013[2].str.contains('Argentina') == False]
FA2013 = FA2013[FA2013[2].str.contains('Russia') == False]
FA2013 = FA2013[FA2013[2].str.contains('China') == False]
FA2013 = FA2013[FA2013[2].str.contains('Greece') == False]
FA2013 = FA2013[FA2013[2].str.contains('Israel') == False]
FA2013 = FA2013[FA2013[2].str.contains('G League') == False]
FA2013 = FA2013[FA2013[2].str.contains('Italy') == False]
FA2013 = FA2013[FA2013[2].str.contains('Philippines') == False]
FA2013 = FA2013[FA2013[2].str.contains('France') == False]
FA2013 = FA2013[FA2013[2].str.contains('Turkey') == False]
FA2013 = FA2013[FA2013[2].str.contains('Germany') == False]
FA2013 = FA2013[FA2013[2].str.contains('Estonia') == False]
FA2013 = FA2013[FA2013[2].str.contains('Hungary') == False]
FA2013 = FA2013[FA2013[2].str.contains('Dominican Republic') == False]
FA2013 = FA2013[FA2013[2].str.contains('Puerto Rico') == False]
FA2013 = FA2013[FA2013[2].str.contains('Lebanon') == False]
FA2013 = FA2013[FA2013[2].str.contains('Australia') == False]
FA2013 = FA2013[FA2013[2].str.contains('Iraq') == False]
FA2013 = FA2013[FA2013[2].str.contains('Slovenia') == False]
FA2013 = FA2013[FA2013[2].str.contains('Belgium') == False]
FA2013 = FA2013[FA2013[2].str.contains('Serbia') == False]
FA2013 = FA2013[FA2013[2].str.contains('Brazil') == False]
FA2013 = FA2013[FA2013[2].str.contains('Venezuela') == False]
FA2013 = FA2013[FA2013[2].str.contains('Lithuania') == False]
FA2013 = FA2013[FA2013[2].str.contains('Ukraine') == False]
FA2013 = FA2013[FA2013[2].str.contains('Japan') == False]
FA2013 = FA2013[FA2013[2].str.contains('ABA') == False]
FA2013 = FA2013[FA2013[2].str.contains('Bulgaria') == False]
FA2013 = FA2013[FA2013[2].str.contains('PBL') == False]
FA2013 = FA2013[FA2013[2].str.contains('Latvia') == False]

# %%
FA2013 = FA2013[0]

# %%
FA2013.to_csv('2013_Free_Agents.csv', index=False)

# %% [markdown]
# # 2012 Free Agents

# %%
html = wp.page("List of 2012–13 NBA season transactions").html().encode("UTF-8")
FA2012 = pd.read_html(html)[5]
FA2012.head()
# Out:
#                      0                                        1  \
# 0               Player                              Date signed
# 1    Lavoy Allen (RFA)                                  July 11
# 2            Ray Allen                               Miami Heat
# 3  Ryan Anderson (RFA)  New Orleans Hornets(via sign and trade)
# 4         Marcus Camby      New York Knicks(via sign and trade)
#
#                     2            3    4
# 0            New team  Former team  Ref
# 1  Philadelphia 76ers         [77]  NaN
# 2      Boston Celtics         [77]  NaN
# 3       Orlando Magic         [77]  NaN
# 4     Houston Rockets         [77]  NaN

# %%
FA2012 = FA2012[:269]

# %%
FA2012[0] = FA2012[0].str.replace('*','')
FA2012[0] = FA2012[0].str.replace('(RFA)','')
FA2012[0] = FA2012[0].str.replace(')','')
FA2012[0] = FA2012[0].str.replace('(','')
FA2012[0] = FA2012[0].str.replace('[','')
FA2012[0] = FA2012[0].str.replace('v]','')
FA2012[0] = FA2012[0].str.replace('e]','')
FA2012[0] = FA2012[0].str.replace('x]','')
FA2012[0] = FA2012[0].str.replace('aa]','')
FA2012[0] = FA2012[0].str.replace(']','')
FA2012[0] = FA2012[0].str.replace('P. J.', 'P.J.')
FA2012[0] = FA2012[0].str.replace('J. J.', 'J.J.')
FA2012[0] = FA2012[0].str.replace('C. J.', 'C.J.')
FA2012[0] = FA2012[0].str.replace('K. J.', 'K.J.')
FA2012[0] = FA2012[0].str.replace('L. J.', 'L.J.')
FA2012[0] = FA2012[0].str.replace('V. J.', 'V.J.')
FA2012[0] = FA2012[0].str.replace('J. P.', 'J.P.')
FA2012[0] = FA2012[0].str.replace('D. J.', 'D.J.')
FA2012[0] = FA2012[0].str.replace('J. R.', 'J.R.')
FA2012[0] = FA2012[0].str.replace('T. J.', 'T.J.')
FA2012[0] = FA2012[0].str.replace('A. J.', 'A.J.')
FA2012[0] = FA2012[0].str.replace('O. J.', 'O.J.')
FA2012[0] = FA2012[0].str.replace('ć', 'c')
FA2012[0] = FA2012[0].str.replace('ê', 'e')
FA2012[0] = FA2012[0].str.replace('í', 'i')
FA2012[0] = FA2012[0].str.replace('š', 's')
FA2012[0] = FA2012[0].str.replace('é', 'e')
FA2012[0] = FA2012[0].str.replace('İ', 'I')
FA2012[0] = FA2012[0].str.replace('ž', 'z')
FA2012[0] = FA2012[0].str.replace('ó', 'o')
FA2012[0] = FA2012[0].str.replace('á', 'a')
FA2012[0] = FA2012[0].str.replace('ü', 'u')
FA2012[0] = FA2012[0].str.replace('ğ', 'g')
FA2012[0] = FA2012[0].str.replace(', Jr.', ' Jr.')



FA2012[0] = FA2012[0].str.replace('ÄiÄ', 'cic')
FA2012[0] = FA2012[0].str.replace('P.ice', ' Price')
FA2012[0] = FA2012[0].str.replace('Ã', 'O')
FA2012[0] = FA2012[0].str.replace('ÅÄ±', 'si')
FA2012[0] = FA2012[0].str.replace('Ä', 'c')
FA2012[0] = FA2012[0].str.replace('Ä°', 'I')

# %%
FA2012 = FA2012[FA2012[2].str.contains('undrafted') == False]
FA2012 = FA2012[FA2012[2].str.contains('D-League') == False]
FA2012 = FA2012[FA2012[2].str.contains('Spain') == False]
FA2012 = FA2012[FA2012[2].str.contains('Argentina') == False]
FA2012 = FA2012[FA2012[2].str.contains('Russia') == False]
FA2012 = FA2012[FA2012[2].str.contains('China') == False]
FA2012 = FA2012[FA2012[2].str.contains('Greece') == False]
FA2012 = FA2012[FA2012[2].str.contains('Israel') == False]
FA2012 = FA2012[FA2012[2].str.contains('G League') == False]
FA2012 = FA2012[FA2012[2].str.contains('Italy') == False]
FA2012 = FA2012[FA2012[2].str.contains('Philippines') == False]
FA2012 = FA2012[FA2012[2].str.contains('France') == False]
FA2012 = FA2012[FA2012[2].str.contains('Turkey') == False]
FA2012 = FA2012[FA2012[2].str.contains('Germany') == False]
FA2012 = FA2012[FA2012[2].str.contains('Estonia') == False]
FA2012 = FA2012[FA2012[2].str.contains('Hungary') == False]
FA2012 = FA2012[FA2012[2].str.contains('Dominican Republic') == False]
FA2012 = FA2012[FA2012[2].str.contains('Puerto Rico') == False]
FA2012 = FA2012[FA2012[2].str.contains('Lebanon') == False]
FA2012 = FA2012[FA2012[2].str.contains('Australia') == False]
FA2012 = FA2012[FA2012[2].str.contains('Iraq') == False]
FA2012 = FA2012[FA2012[2].str.contains('Slovenia') == False]
FA2012 = FA2012[FA2012[2].str.contains('Belgium') == False]
FA2012 = FA2012[FA2012[2].str.contains('Serbia') == False]
FA2012 = FA2012[FA2012[2].str.contains('Brazil') == False]
FA2012 = FA2012[FA2012[2].str.contains('Venezuela') == False]
FA2012 = FA2012[FA2012[2].str.contains('Lithuania') == False]
FA2012 = FA2012[FA2012[2].str.contains('Ukraine') == False]
FA2012 = FA2012[FA2012[2].str.contains('Japan') == False]
FA2012 = FA2012[FA2012[2].str.contains('ABA') == False]
FA2012 = FA2012[FA2012[2].str.contains('Bulgaria') == False]
FA2012 = FA2012[FA2012[2].str.contains('PBL') == False]
FA2012 = FA2012[FA2012[2].str.contains('Latvia') == False]
FA2012 = FA2012[FA2012[2].str.contains('New Zealand') == False]
FA2012 = FA2012[FA2012[2].str.contains('Romania') == False]
FA2012 = FA2012[FA2012[2].str.contains('Tunisia') == False]
FA2012 = FA2012[FA2012[2].str.contains('Poland') == False]
FA2012 = FA2012[FA2012[2].str.contains('Croatia') == False]
FA2012 = FA2012[FA2012[2].str.contains('Austria') == False]
FA2012 = FA2012[FA2012[2].str.contains('Czech Republic') == False]
FA2012 = FA2012[FA2012[2].str.contains('Retired') == False]

# %%
FA2012 = FA2012[0]

# %%
FA2012.to_csv('2012_Free_Agents.csv', index=False)

# %% [markdown]
# # 2011 Free Agents

# %%
html = wp.page("List of 2011–12 NBA season transactions").html().encode("UTF-8")
FA2011 = pd.read_html(html)[6]
FA2011.head()
# Out:
#                       0              1                           2  \
# 0                Player    Date signed                    New team
# 1         Jason Collins     December 9               Atlanta Hawks
# 2          Ivan Johnson  Atlanta Hawks  Qingdao DoubleStar (China)
# 3         Tracy McGrady  Atlanta Hawks             Detroit Pistons
# 4  Vladimir RadmanoviÄ  Atlanta Hawks       Golden State Warriors
#
#              3    4
# 0  Former team  Ref
# 1         [79]  NaN
# 2         [79]  NaN
# 3         [79]  NaN
# 4         [80]  NaN

# %%
FA2011 = FA2011[:122]

# %%
FA2011[0] = FA2011[0].str.replace('*','')
FA2011[0] = FA2011[0].str.replace('(RFA)','')
FA2011[0] = FA2011[0].str.replace(')','')
FA2011[0] = FA2011[0].str.replace('(','')
FA2011[0] = FA2011[0].str.replace('[','')
FA2011[0] = FA2011[0].str.replace('v]','')
FA2011[0] = FA2011[0].str.replace('e]','')
FA2011[0] = FA2011[0].str.replace('x]','')
FA2011[0] = FA2011[0].str.replace('aa]','')
FA2011[0] = FA2011[0].str.replace(']','')
FA2011[0] = FA2011[0].str.replace('P. J.', 'P.J.')
FA2011[0] = FA2011[0].str.replace('J. J.', 'J.J.')
FA2011[0] = FA2011[0].str.replace('C. J.', 'C.J.')
FA2011[0] = FA2011[0].str.replace('K. J.', 'K.J.')
FA2011[0] = FA2011[0].str.replace('L. J.', 'L.J.')
FA2011[0] = FA2011[0].str.replace('V. J.', 'V.J.')
FA2011[0] = FA2011[0].str.replace('J. P.', 'J.P.')
FA2011[0] = FA2011[0].str.replace('D. J.', 'D.J.')
FA2011[0] = FA2011[0].str.replace('J. R.', 'J.R.')
FA2011[0] = FA2011[0].str.replace('T. J.', 'T.J.')
FA2011[0] = FA2011[0].str.replace('A. J.', 'A.J.')
FA2011[0] = FA2011[0].str.replace('O. J.', 'O.J.')
FA2011[0] = FA2011[0].str.replace('ć', 'c')
FA2011[0] = FA2011[0].str.replace('ê', 'e')
FA2011[0] = FA2011[0].str.replace('í', 'i')
FA2011[0] = FA2011[0].str.replace('š', 's')
FA2011[0] = FA2011[0].str.replace('é', 'e')
FA2011[0] = FA2011[0].str.replace('İ', 'I')
FA2011[0] = FA2011[0].str.replace('ž', 'z')
FA2011[0] = FA2011[0].str.replace('ó', 'o')
FA2011[0] = FA2011[0].str.replace('á', 'a')
FA2011[0] = FA2011[0].str.replace('ü', 'u')
FA2011[0] = FA2011[0].str.replace('ğ', 'g')
FA2011[0] = FA2011[0].str.replace(', Jr.', ' Jr.')

FA2011[0] = FA2011[0].str.replace('Ä', 'c')
FA2011[0] = FA2011[0].str.replace('Ãª', 'e')
FA2011[0] = FA2011[0].str.replace('JosÃ© Juan', 'J.J.')
FA2011[0] = FA2011[0].str.replace('Ã«', 'e')
FA2011[0] = FA2011[0].str.replace('Ã©', 'e')

# %%
FA2011 = FA2011[FA2011[2].str.contains('undrafted') == False]
FA2011 = FA2011[FA2011[2].str.contains('D-League') == False]
FA2011 = FA2011[FA2011[2].str.contains('Spain') == False]
FA2011 = FA2011[FA2011[2].str.contains('Argentina') == False]
FA2011 = FA2011[FA2011[2].str.contains('Russia') == False]
FA2011 = FA2011[FA2011[2].str.contains('China') == False]
FA2011 = FA2011[FA2011[2].str.contains('Greece') == False]
FA2011 = FA2011[FA2011[2].str.contains('Israel') == False]
FA2011 = FA2011[FA2011[2].str.contains('G League') == False]
FA2011 = FA2011[FA2011[2].str.contains('Italy') == False]
FA2011 = FA2011[FA2011[2].str.contains('Philippines') == False]
FA2011 = FA2011[FA2011[2].str.contains('France') == False]
FA2011 = FA2011[FA2011[2].str.contains('Turkey') == False]
FA2011 = FA2011[FA2011[2].str.contains('Germany') == False]
FA2011 = FA2011[FA2011[2].str.contains('Estonia') == False]
FA2011 = FA2011[FA2011[2].str.contains('Hungary') == False]
FA2011 = FA2011[FA2011[2].str.contains('Dominican Republic') == False]
FA2011 = FA2011[FA2011[2].str.contains('Puerto Rico') == False]
FA2011 = FA2011[FA2011[2].str.contains('Lebanon') == False]
FA2011 = FA2011[FA2011[2].str.contains('Australia') == False]
FA2011 = FA2011[FA2011[2].str.contains('Iraq') == False]
FA2011 = FA2011[FA2011[2].str.contains('Slovenia') == False]
FA2011 = FA2011[FA2011[2].str.contains('Belgium') == False]
FA2011 = FA2011[FA2011[2].str.contains('Serbia') == False]
FA2011 = FA2011[FA2011[2].str.contains('Brazil') == False]
FA2011 = FA2011[FA2011[2].str.contains('Venezuela') == False]
FA2011 = FA2011[FA2011[2].str.contains('Lithuania') == False]
FA2011 = FA2011[FA2011[2].str.contains('Ukraine') == False]
FA2011 = FA2011[FA2011[2].str.contains('Japan') == False]
FA2011 = FA2011[FA2011[2].str.contains('ABA') == False]
FA2011 = FA2011[FA2011[2].str.contains('Bulgaria') == False]
FA2011 = FA2011[FA2011[2].str.contains('PBL') == False]
FA2011 = FA2011[FA2011[2].str.contains('Latvia') == False]
FA2011 = FA2011[FA2011[2].str.contains('New Zealand') == False]
FA2011 = FA2011[FA2011[2].str.contains('Romania') == False]
FA2011 = FA2011[FA2011[2].str.contains('Tunisia') == False]
FA2011 = FA2011[FA2011[2].str.contains('Poland') == False]
FA2011 = FA2011[FA2011[2].str.contains('Croatia') == False]
FA2011 = FA2011[FA2011[2].str.contains('Austria') == False]
FA2011 = FA2011[FA2011[2].str.contains('Czech Republic') == False]
FA2011 = FA2011[FA2011[2].str.contains('Retired') == False]
FA2011 = FA2011[FA2011[2].str.contains('None') == False]

# %%
FA2011 = FA2011[0]

# %%
FA2011.to_csv('2011_Free_Agents.csv', index=False)

# %% [markdown]
# # 2010 Free Agents

# %%
html = wp.page("List of 2010–11 NBA season transactions").html().encode("UTF-8")
FA2010 = pd.read_html(html)[5][1:]
FA2010.head()
# Out:
#                0                   1                     2            3
# 1         Player              Signed              New team  Former team
# 2  Channing Frye              July 8          Phoenix Suns          NaN
# 3    Chris Duhon       Orlando Magic       New York Knicks          NaN
# 4       Rudy Gay   Memphis Grizzlies                   NaN          NaN
# 5    Steve Blake  Los Angeles Lakers  Los Angeles Clippers          NaN

# %%
FA2010 = FA2010[:112]

# %%
FA2010[0] = FA2010[0].str.replace('*','')
FA2010[0] = FA2010[0].str.replace('(RFA)','')
FA2010[0] = FA2010[0].str.replace(')','')
FA2010[0] = FA2010[0].str.replace('(','')
FA2010[0] = FA2010[0].str.replace('[','')
FA2010[0] = FA2010[0].str.replace('v]','')
FA2010[0] = FA2010[0].str.replace('e]','')
FA2010[0] = FA2010[0].str.replace('x]','')
FA2010[0] = FA2010[0].str.replace('aa]','')
FA2010[0] = FA2010[0].str.replace(']','')
FA2010[0] = FA2010[0].str.replace('P. J.', 'P.J.')
FA2010[0] = FA2010[0].str.replace('J. J.', 'J.J.')
FA2010[0] = FA2010[0].str.replace('C. J.', 'C.J.')
FA2010[0] = FA2010[0].str.replace('K. J.', 'K.J.')
FA2010[0] = FA2010[0].str.replace('L. J.', 'L.J.')
FA2010[0] = FA2010[0].str.replace('V. J.', 'V.J.')
FA2010[0] = FA2010[0].str.replace('J. P.', 'J.P.')
FA2010[0] = FA2010[0].str.replace('D. J.', 'D.J.')
FA2010[0] = FA2010[0].str.replace('J. R.', 'J.R.')
FA2010[0] = FA2010[0].str.replace('T. J.', 'T.J.')
FA2010[0] = FA2010[0].str.replace('A. J.', 'A.J.')
FA2010[0] = FA2010[0].str.replace('O. J.', 'O.J.')
FA2010[0] = FA2010[0].str.replace('ć', 'c')
FA2010[0] = FA2010[0].str.replace('ê', 'e')
FA2010[0] = FA2010[0].str.replace('í', 'i')
FA2010[0] = FA2010[0].str.replace('š', 's')
FA2010[0] = FA2010[0].str.replace('é', 'e')
FA2010[0] = FA2010[0].str.replace('İ', 'I')
FA2010[0] = FA2010[0].str.replace('ž', 'z')
FA2010[0] = FA2010[0].str.replace('ó', 'o')
FA2010[0] = FA2010[0].str.replace('á', 'a')
FA2010[0] = FA2010[0].str.replace('ü', 'u')
FA2010[0] = FA2010[0].str.replace('ğ', 'g')
FA2010[0] = FA2010[0].str.replace(', Jr.', ' Jr.')
FA2010[0] = FA2010[0].str.replace('Ž', 'Z')
FA2010[0] = FA2010[0].str.replace('ū', 'u')

FA2010[0] = FA2010[0].str.replace('R.dick', ' Redick')

# %%
FA2010 = FA2010[0]

# %%
FA2010.to_csv('2010_Free_Agents.csv', index=False)

# %% [markdown]
# # 2009 Free Agents

# %%
html = wp.page("List of 2009–10 NBA season transactions").html().encode("UTF-8")
FA2009 = pd.read_html(html)[6][2:]
FA2009.head()
# Out:
#                  0                   1                2                   3
# 2             July                 NaN              NaN                 NaN
# 3     Trevor Ariza              July 8  Houston Rockets  Los Angeles Lakers
# 4       Ron Artest  Los Angeles Lakers  Houston Rockets                 NaN
# 5  Rasheed Wallace      Boston Celtics  Detroit Pistons                 NaN
# 6       Ben Gordon     Detroit Pistons    Chicago Bulls                 NaN

# %%
FA2009 = FA2009[:91]

# %%
FA2009[0] = FA2009[0].str.replace('ã', 'a')
FA2009[0] = FA2009[0].str.replace('İ', 'I')
FA2009[0] = FA2009[0].str.replace('ć', 'c')
FA2009[0] = FA2009[0].str.replace('ž', 'z')
FA2009[0] = FA2009[0].str.replace('C. J.', 'C.J.')

# %%
FA2009 = FA2009[FA2009[0] != 'August']
FA2009 = FA2009[FA2009[0] != 'September']

# %%
FA2009 = FA2009[0]

# %%
FA2009.to_csv('2009_Free_Agents.csv', index=False)

# %% [markdown]
# # 2008 Free Agents

# %%
html = wp.page("List of 2008–09 NBA season transactions").html().encode("UTF-8")
FA2008 = pd.read_html(html)[4]
FA2008.head()
# Out:
#               0                    1                 2                3
# 0        Player          Date signed          New team      Former team
# 1  Gerald Green               July 3  Dallas Mavericks  Houston Rockets
# 2  Hassan Adams               July 6   Toronto Raptors    Teramo Basket
# 3   J. J. Barea               July 9  Dallas Mavericks              NaN
# 4    Chris Paul  New Orleans Hornets               NaN              NaN

# %%
FA2008[0] = FA2008[0].str.replace('J. J.', 'J.J.')
FA2008[0] = FA2008[0].str.replace('é', 'e')
FA2008[0] = FA2008[0].str.replace('ó', 'o')
FA2008[0] = FA2008[0].str.replace('á', 'a')
FA2008[0] = FA2008[0].str.replace('ć', 'c')
FA2008[0] = FA2008[0].str.replace(', Jr.', ' Jr.')

# %%
FA2008 = FA2008[0]

# %%
FA2008.to_csv('2008_Free_Agents.csv', index=False)
